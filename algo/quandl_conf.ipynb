# %%
import quandl as q
import pandas as pd

# %%
q.ApiConfig.api_key = 'nW3x7YNG-__rZF7pDzYs'

# %%
data = q.get('FRED/CPILFESL', start_date='2010-10-01', end_date='2021-11-05')
data2 = q.get('FRED/DTWEXM', start_date='2010-10-01', end_date='2031-11-05')
data3 = q.get('FRED/DSPIC96', start_date='2010-10-01', end_date='2021-11-05')

# %%
print (len(data), len(data2), len(data3))
# Out:
# 134 2299 134

# %%
data2.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#Stock Market Confidence Indices - United States Valuation Index Data - Individual

data4 = q.get('YALE/US_CONF_INDEX_VAL_INDIV', start_date='2010-10-01', end_date='2021-11-05')

# %%
data4.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#Historical Housing Market Data - Nominal Home Price Index
data4 = q.get('YALE/NHPI', start_date='2010-10-01', end_date='2021-11-05')
data4.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#gold Price london fixed
data4 = q.get('LBMA/GOLD', start_date='2010-10-01', end_date='2031-11-05')
data4.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
data4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2912 entries, 2010-10-01 to 2022-04-07
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   USD (AM)   2912 non-null   float64
#  1   USD (PM)   2888 non-null   float64
#  2   GBP (AM)   2912 non-null   float64
#  3   GBP (PM)   2888 non-null   float64
#  4   EURO (AM)  2912 non-null   float64
#  5   EURO (PM)  2888 non-null   float64
# dtypes: float64(6)
# memory usage: 159.2 KB

# %%
DATAUSD = data4['USD (AM)']
DATAUSD.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
data4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2912 entries, 2010-10-01 to 2022-04-07
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   USD (AM)   2912 non-null   float64
#  1   USD (PM)   2888 non-null   float64
#  2   GBP (AM)   2912 non-null   float64
#  3   GBP (PM)   2888 non-null   float64
#  4   EURO (AM)  2912 non-null   float64
#  5   EURO (PM)  2888 non-null   float64
# dtypes: float64(6)
# memory usage: 159.2 KB

# %%
datausd = pd.DataFrame(DATAUSD)
type(datausd)
# Out:
# pandas.core.frame.DataFrame
